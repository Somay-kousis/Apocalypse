# %% [markdown]
# # Action-Rate Threshold Backtesting
#
# This notebook computes the headline number by backtesting a per-identity action-rate threshold against HuggingFace's incident data (e.g., the 7,677-action spike on Day 3). It determines how many hours earlier quarantine would have fired.
